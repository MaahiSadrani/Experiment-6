# %% [markdown]
# Name - Maahi Sadrani
# PRN - 25070123069

# %%
# Experiment 06:
# Study of conditional statements in python

# %%
# Q1). Check whether a given number is positive negative or zero

num = int(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: -62
# The number is negative.

# %%
# Q2). Check whether a given number is even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
 print("The given number is even.")
else:
 print("The given number is odd.")
# Out:
# Enter a number: 22
# The given number is even.

# %%
# Q3). Find the largest number out the three given numbers

a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))
if a >= b and a >= c:
 print("a is the largest number.")
elif b >= a and b >= c:
 print("b is the largest number.")
else:
 print("c is the largest number.")
# Out:
# Enter the first number:6
# Enter the second number:6
# Enter the third number:3
# a is the largest number.

# %%
# Q4). Get thbe input from the user for one subject and
# Calculate grade using if else if

marks = float(input("Enter your marks:"))

if marks >= 90:
 print("Grade: A")
elif marks >= 75:
  print("Grade: B")
elif marks >= 60:
  print("Grade: C")
elif marks >=40:
  print("Grade: D")
else:
  print("Grade: F")
# Out:
# Enter your marks:86.2
# Grade: B

# %%
# Q5). To fin if the given year is a leap year or not

year = int(input("Enter a year:"))
if year % 4 == 0 or (year % 100 != 0  and year % 400 == 0):
 print("The given year is a leap year.")
else:
  print("The given year is not a leap year.")
# Out:
# Enter a year:2000
# The given year is a leap year.

# %%
# Q6). To input the date month and year and increment it by 1
